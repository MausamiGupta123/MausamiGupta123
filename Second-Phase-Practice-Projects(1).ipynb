# %%
import pandas as pd 
import numpy as np
import  warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns

df.info()

df.describe()

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df = df.drop (columns = ['Country','Region'])
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize = (200,150),facecolor = 'red')
plotnumber = 1

for column in df:
    if plotnumber<=10:
        ax = plt.subplot(5,6,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 175)
        
    plotnumber+=1
plt.tight_layout()

# %%
titanic_train = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv")
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
titanic_train["Survived"].replace({0:"Dead",1:"Survived"},inplace = True)

# %%
titanic_train["Survived"].head()
# Out:
# 0        Dead
# 1    Survived
# 2    Survived
# 3    Survived
# 4        Dead
# Name: Survived, dtype: object

# %%
# finding count of total male/female, Dead and servived passengers using crosstab (You need two column)
dd_sv_cnt = pd.crosstab(titanic_train['Survived'],titanic_train['Sex'],margins = True)
dd_sv_cnt
# Out:
# Sex       female  male  All
# Survived
# Dead          81   468  549
# Survived     233   109  342
# All          314   577  891

# %%
# Gender vs Pclass count
class_gen_cnt = pd.crosstab(titanic_train['Sex'],titanic_train['Pclass'],margins = True)
class_gen_cnt
# Out:
# Pclass    1    2    3  All
# Sex
# female   94   76  144  314
# male    122  108  347  577
# All     216  184  491  891

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
age_missing = titanic_train[titanic_train['Age'].isna()]

#or

#age_missing = titanic_train[titanic_train.Age.isin(['NaN'])]

age_missing
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6      Dead       3                          Moran, Mr. James
# 17            18  Survived       2              Williams, Mr. Charles Eugene
# 19            20  Survived       3                   Masselmani, Mrs. Fatima
# 26            27      Dead       3                   Emir, Mr. Farred Chehab
# 28            29  Survived       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860      Dead       3                          Razi, Mr. Raihed
# 863          864      Dead       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Dead       3               van Melkebeke, Mr. Philemon
# 878          879      Dead       3                        Laleff, Mr. Kristo
# 888          889      Dead       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
with_age = titanic_train[titanic_train['Age'].notnull()]

#or

#with_age = titanic_train[~titanic_train.Age.isin(['NaN'])]

with_age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Dead       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Dead       3
# ..           ...       ...     ...
# 885          886      Dead       3
# 886          887      Dead       2
# 887          888  Survived       1
# 889          890  Survived       1
# 890          891      Dead       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
with_age = titanic_train[~titanic_train.Age.isin(['NaN'])]
with_age
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Dead       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Dead       3
# ..           ...       ...     ...
# 886          887      Dead       2
# 887          888  Survived       1
# 888          889      Dead       3
# 889          890  Survived       1
# 890          891      Dead       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
max(titanic_train["Fare"])
# Out:
# 512.3292

# %%
max_ = titanic_train[titanic_train.Fare == max(titanic_train["Fare"])]
max_
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259  Survived       1                    Ward, Miss. Anna
# 679          680  Survived       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738  Survived       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
min_ = titanic_train[titanic_train.Fare == min(titanic_train["Fare"])]
min_
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180      Dead       3               Leonard, Mr. Lionel  male
# 263          264      Dead       1             Harrison, Mr. William  male
# 271          272  Survived       3      Tornquist, Mr. William Henry  male
# 277          278      Dead       2       Parkes, Mr. Francis "Frank"  male
# 302          303      Dead       3   Johnson, Mr. William Cahoone Jr  male
# 413          414      Dead       2    Cunningham, Mr. Alfred Fleming  male
# 466          467      Dead       2             Campbell, Mr. William  male
# 481          482      Dead       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598      Dead       3               Johnson, Mr. Alfred  male
# 633          634      Dead       1     Parr, Mr. William Henry Marsh  male
# 674          675      Dead       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
class_female = titanic_train[titanic_train.Pclass.isin([1]) & titanic_train.Sex.isin(["female"])]
class_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2  Survived       1
# 3              4  Survived       1
# 11            12  Survived       1
# 31            32  Survived       1
# 52            53  Survived       1
# ..           ...       ...     ...
# 856          857  Survived       1
# 862          863  Survived       1
# 871          872  Survived       1
# 879          880  Survived       1
# 887          888  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
class_female = titanic_train[titanic_train.Pclass.isin([2]) & titanic_train.Sex.isin(["female"])]
class_female
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10  Survived       2
# 15            16  Survived       2
# 41            42      Dead       2
# 43            44  Survived       2
# 53            54  Survived       2
# ..           ...       ...     ...
# 854          855      Dead       2
# 865          866  Survived       2
# 866          867  Survived       2
# 874          875  Survived       2
# 880          881  Survived       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
class_female = titanic_train[titanic_train.Pclass.isin([3]) & titanic_train.Sex.isin(["female"])]
class_female
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3  Survived       3
# 8              9  Survived       3
# 10            11  Survived       3
# 14            15      Dead       3
# 18            19      Dead       3
# ..           ...       ...     ...
# 863          864      Dead       3
# 875          876  Survived       3
# 882          883      Dead       3
# 885          886      Dead       3
# 888          889      Dead       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...
