# %% [markdown]
# ## Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. Youhave to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10jobs data.
# **This task will be done in following steps:**
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter thelocation” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data

# %% [markdown]
# #### Import Required Libraries

# %%
! pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.naukri.com"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 url = "https://www.naukri.com"
# ----> 2 driver.get(url)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# ...

# %%
# finding element for job search bar
designation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
designation.send_keys('Data Analyst')

# %%
# finding element for loc search bar
loctation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
loctation.send_keys('Bangalore')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
job_title = []
job_location = []
Company_name = []
experience_required = []

# %%
# extract  the job title  from the tags
title_tags=driver.find_elements(By.XPATH,"//a[@class='title ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
    
    
# extract  the job location  from the tags
location_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft locWdth']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
    
    
# extract  the Company name  from the tags
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)
    
    
    
    
    
# extract  the job experience  from the tags
experience_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft expwdth']")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(Company_name),len(experience_required))
# Out:
# 10 10 10 10

# %% [markdown]
# ## Creating a DataFarme for the Data Analyst jobs

# %%
df=pd.DataFrame({})
df['Title']=job_title[0:10]
df['Company']=Company_name[0:10]
df['Experience_required']=experience_required[0:10]
df['Location']=job_location[0:10]

df
# Out:
#                                                Title  \
# 0                                       Data Analyst
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3  Oracle Tax & Treasury PMO Contractor (Data Ana...
# 4                                       Data Analyst
# 5                                       Data Analyst
# 6                                       Data Analyst
# 7                                       Data Analyst
# 8                         Data Analyst - Contractual
# 9                         Data Analyst - Contractual
#
#                             Company Experience_required             Location
# 0                      Globals Ites             2-3 Yrs  Bangalore/Bengaluru
# 1                            Varite             4-5 Yrs  Bangalore/Bengaluru
# 2      Cynosure Corporate Solutions             2-7 Yrs  Bangalore/Bengaluru
# ...

# %%
driver.close()

# %% [markdown]
# ## Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# **This task will be done in following steps:**
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
# let's first connect to the web driver
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.naukri.com"
driver.get(url)

# %%
# finding element for job search bar
designation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
designation.send_keys('Data  Scientist')

# %%
# finding element for loc search bar
loctation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
loctation.send_keys('Bangalore')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
job_title = []
job_location = []
Company_name = []
experience_required = []

# %%
# extract  the job title  from the tags
title_tags=driver.find_elements(By.XPATH,"//a[@class='title ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
    
    
# extract  the job location  from the tags
location_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft locWdth']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
    
    
# extract  the Company name  from the tags
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)
    
    
    
    
    
# extract  the job experience  from the tags
experience_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft expwdth']")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(Company_name),len(experience_required))
# Out:
# 10 10 10 10

# %% [markdown]
# ## Creating a DataFarme for the Data Analyst jobs

# %%
df=pd.DataFrame({})
df['Data Scientist']=job_title[0:10]
df['Company']=Company_name[0:10]
df['Experience_required']=experience_required[0:10]
df['Location']=job_location[0:10]

df
# Out:
#                                       Data Scientist                Company  \
# 0  Data Science Professional - IBM SPSS Statistic...  Hexaware Technologies
# 1                            Data Science Specialist              Accenture
# 2                   Analystics & Modeling Specialist              Accenture
# 3                              Senior data scientist      Fractal Analytics
# 4                                 Data Scientist_NLP      Fractal Analytics
# 5                                     Data Scientist      Fractal Analytics
# 6                    Machine Learning (AI) Architect             Persistent
# 7       Manager - Innovations Hub - Machine Learning                    PwC
# 8            Senior Engineer Consultant Data Science                Verizon
# 9            Senior Engineer Consultant-Data Science                Verizon
#
#   Experience_required                                           Location
# ...

# %%
driver.close()

# %% [markdown]
# ## Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# **You have to use the location and salary filter.**
#
# **You have to scrape data for “Data Scientist” designation for first 10 job results.**
#
# **You have to scrape the job-title, job-location, company name, experience required.**
#
#
# **The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhsThe task will be done as shown in the below steps:**
#
# 1. first get thewebpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the searchbutton.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results youget.
# 6. Finally create a dataframe of the scraped data.

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.naukri.com"
driver.get(url)

# %%
# finding element for job search bar
designation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
designation.send_keys('Data  Scientist')

# %%
# finding element for loc search bar
loctation = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
loctation.send_keys('Delhi/NCR')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
job_title = []
job_location = []
Company_name = []
experience_required = []
Salary_required =[]

# %%
# extract  the job title  from the tags
title_tags=driver.find_elements(By.XPATH,"//a[@class='title ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
    
    
    
# extract  the job location  from the tags
location_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft locWdth']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
    
    
    
# extract  the Company name  from the tags
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    Company_name.append(company)
    
    
    
    
    
# extract  the job experience  from the tags
experience_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft expwdth']")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)
       
        
        
# extract  the salary   from the tags
salary_tags=driver.find_elements(By.XPATH,"//div[@class='filterOptns']")
for i in salary_tags[0:10]:
    sal=i.text
    Salary_required.append(sal)

# %%
print(len(job_title),len(job_location),len(Company_name),len(experience_required),len(Salary_required))
# Out:
# 10 10 10 10 10

# %% [markdown]
# ## Creating a DataFarme for the Data Analyst jobs

# %%
df=pd.DataFrame({})
df['Data Scientist']=job_title[0:10]
df['Company']=Company_name[0:10]
df['Experience_required']=experience_required[0:10]
df['Location']=job_location[0:10]
df['Salary']=Salary_required[0:10]


df
# Out:
#                                       Data Scientist  \
# 0  Data Science Professional - IBM SPSS Statistic...
# 1                              Senior data scientist
# 2                                 Data Scientist_NLP
# 3                                     Data Scientist
# 4                    Machine Learning (AI) Architect
# 5                                       Data Science
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                        Company Experience_required  \
# 0        Hexaware Technologies             5-8 Yrs
# 1            Fractal Analytics             4-8 Yrs
# 2            Fractal Analytics            5-11 Yrs
# 3            Fractal Analytics             3-7 Yrs
# 4                   Persistent            5-12 Yrs
# 5                     Skillety            7-10 Yrs
# ...

# %%
driver.close()

# %% [markdown]
# ## Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# **1. Brand**
#
# **2. ProductDescription**
#
# **3. Price**
#
# **The attributes which you have to scrape is ticked marked in the below image.**
#
# **To scrape the data you have to go through following steps:**
# 1. Go to Flipkart webpage by url :https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data asusual
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , thenclick on it.
# 5. Now scrape data from this page asusual
# 6. Repeat this until you get data for 100sunglasses.

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
products = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
products.send_keys("sunglasses")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
Brand = []
ProductDescription = []
Price = []

# %%
brand_tags=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
for i in brand_tags[0:100]:
    brand=i.text
    brand_tags.append(brand)
    
    
    
Product_tags=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
for i in Product_tags[0:100]:
    Product=i.text
    Product_tags.append(Product)
    
Price_tags=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
for i in Price_tags[0:100]:
    Price=i.text
    Price_tags.append(Price)

# %%
df=pd.DataFrame({})
df['Brand']=brand_tags[40:100]
df['ProductDescription']=Product_tags[40:100] 
df['Price']=Price_tags[40:100]
df
# Out:
#                 Brand                                 ProductDescription  \
# 0       VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 1       VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 2           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 3              PIRASO       UV Protection Aviator Sunglasses (Free Size)
# 4   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 5            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 6              PIRASO           UV Protection Clubmaster Sunglasses (54)
# 7       VINCENT CHASE    by Lenskart UV Protection Round Sunglasses (58)
# 8           Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)
# 9                SRPM             UV Protection Wayfarer Sunglasses (50)
# 10          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 11        Eyewearlabs   Polarized, UV Protection Aviator Sunglasses (56)
# ...

# %%
driver.close()

# %% [markdown]
# ## Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKAR
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.flipkart.com"
driver.get(url)

# %%
products = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
products.send_keys("apple-iphone-11-black-64-gb")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
Product = []
Rating = []
Review_summary =[]
Full_review = []

# %%
product_tags=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in product_tags[0:100]:
    produt=i.text
    product_tags.append(Product)
    
    
    
    
    
    
    
rating_tags=driver.find_elements(By.XPATH,"//span[@id='productRating_LSTMOBFWQ6BXGJCEYNYZXSHRJ_MOBFWQ6BXGJCEYNY_']")
for i in rating_tags[0:100]:
    rating=i.text
    rating_tags.append(rating)
    
    
    
    
review_tags=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK']")
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)
    
    
    
    
full_review_tags=driver.find_elements(By.XPATH,"//div[@class='_3pLy-c row']")
for i in full_review_tags[0:100]:
    full_review=i.text
    full_review_tags.append(full_review)

# %%
df=pd.DataFrame({})
df['review']=review_tags[0:100] 
df['Full_review']=full_review_tags[0:100]

df
# Out:
#                                               review  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2                                                4.6
# 3                                                4.6
#
#                                          Full_review
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  APPLE iPhone 11 (Black, 64 GB)\n4.61,89,523 Ra...
# 3  APPLE iPhone 11 (Black, 128 GB)\n4.61,89,523 R...

# %%
driver.close()

# %% [markdown]
# ## Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
products = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
products.send_keys("sneakers”")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
product_tags=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
for i in product_tags[0:100]:
    produt=i.text
    product_tags.append(Product)
    
    
    
    
    
    
    
rating_tags=driver.find_elements(By.XPATH,"//div[@id='_30jeq3']")
for i in rating_tags[0:100]:
    rating=i.text
    rating_tags.append(rating)
    
    
    
    
review_tags=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")
for i in review_tags[0:100]:
    review=i.text
    review_tags.append(review)

# %%
Product = []
price = []
Review =[]

# %%
df=pd.DataFrame({}) 
df['Product']=product_tags[40:100]
df['price']=Price_tags[40:100]
df['Reivew']=review_tags[40:100]
df
# Out:
#    Product   price   Reivew
# 0       []  ₹1,061  71% off
# 1       []    ₹929  85% off
# 2       []    ₹149  58% off
# 3       []    ₹268  80% off
# 4       []    ₹185  69% off
# 5       []    ₹644  65% off
# 6       []    ₹224  60% off
# 7       []    ₹929  76% off
# 8       []    ₹179  50% off
# 9       []    ₹169  82% off
# 10      []    ₹265  80% off
# 11      []  ₹1,489  80% off
# 12      []    ₹274  78% off
# 13      []    ₹909  64% off
# 14      []    ₹129  66% off
# 15      []    ₹899  57% off
# 16      []    ₹509  42% off
# 17      []    ₹544  42% off
# 18      []    ₹585  86% off
# 19      []    ₹854  60% off
# 20      []    ₹149  50% off
# 21      []     ₹99  42% off
# 22      []    ₹211  70% off
# 23      []    ₹786  70% off
# 24      []    ₹149  75% off
# 25      []    ₹182  78% off
# 26      []    ₹739  60% off
# 27      []    ₹485  40% off
# 28      []    ₹739  50% off
# 29      []    ₹214  73% off
# 30      []    ₹293  49% off
# 31      []  ₹1,470  50% off
# ...

# %%
driver.close()

# %% [markdown]
# ## Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7”After setting the filters scrape first 10 laptops data.
# You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.amazon.in"
driver.get(url)

# %%
# finding element for  search bar
search = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search.send_keys('laptop')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
title_tags=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
for i in title_tags[0:100]:
    title=i.text
    title_tags.append(title)
    
    
    
    
    
    
    
rating_tags=driver.find_elements(By.XPATH,"//span[@class='a-size-base']")
for i in rating_tags[0:100]:
    rating=i.text
    rating_tags.append(rating)
    
    
    
    
price_tags=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-base a-color-base']")
for i in price_tags[0:100]:
    price=i.text
    price_tags.append(price)

# %%
Title=[]
Rating=[]
Price=[]

# %%
df=pd.DataFrame({})
df['Title']=title_tags[22:44]
df['Rating']=rating_tags[22:44]
df['Price']=price_tags[22:44]

df
# Out:
#                                                 Title Rating  \
# 0   Dell Vostro 3420 Laptop,12th Gen Intel Core i3...    4.2
# 1   Fujitsu CH Intel Evo Core i5 11th Gen 13.3" FH...    3.9
# 2   Dell Inspiron 3520 Laptop,12th Gen Intel Core ...    3.6
# 3   HP 255 G8 Laptop with AMD Athlon Silver 3050U ...    3.5
# 4   Acer Extensa 15 Lightweight Laptop Intel Core ...    3.9
# 5   Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...    4.1
# 6   HP 15s, 11th Gen Intel Core i3 8GB RAM/1TB HDD...    4.4
# 7   ASUS Vivobook 14, Intel Core i3-1115G4 11th Ge...    3.4
# 8   HP 245 G8 3S7L2PA Notebook Business Laptop 14 ...    4.1
# 9   ASUS TUF Gaming A15, 15.6"(39.62 cms) FHD 144H...    3.2
# 10  ASUS Vivobook 15, Intel Core i3-1220P 12th Gen...    4.3
# 11  Acer Aspire 3 AMD 3020e Dual core Processor (4...    4.6
# 12  HP 14s, Intel Celeron N4500, 8GB RAM/256GB SSD...    3.1
# 13  Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...    3.7
# ...

# %%
driver.close()

# %% [markdown]
# ## Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuote

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.azquotes.com/"
driver.get(url)

# %%
# finding element for  search bar
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[2]/div[1]/a")
search.send_keys('TopQuote')

# %%
Quote_tags=driver.find_elements(By.XPATH,"//a[@class='title']")
for i in Quote_tags[0:1000]:
    Quote=i.text
    Quote_tags.append(Quote)
    
    
    
    
    
    
    
Author_tags=driver.find_elements(By.XPATH,"//div[@class='author']")
for i in  Author_tags[0:1000]:
    Author=i.text
    Author_tags.append( Author)
    
    
    
    
Type_Of_Quotes_tags=driver.find_elements(By.XPATH,"//div[@class='tags']")
for i in Type_Of_Quotes_tags[0:1000]:
    Type_Of_Quotes=i.text
    Type_Of_Quotes_tags.append(Type_Of_Quotes)

# %%
Quote=[]
Author=[]
Type_Of_Quotes=[]

# %%
df=pd.DataFrame({})
df['Quote']=Quote_tags
df['Author']=Author_tags
df['Type_Of_Quotes']=Type_Of_Quotes_tags

df
# Out:
#                                                  Quote  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# 4    <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                 ...
# 195     When the going gets weird, the weird turn pro.
# 196  When a train goes through a tunnel and it gets...
# 197  If you think you are too small to make a diffe...
# 198  God doesn't require us to succeed, he only req...
# 199    Change your thoughts and you change your world.
#
#                                                 Author  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
driver.close()

# %% [markdown]
# ## Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
 # connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.jagranjosh.com/"
driver.get(url)

# %%
# finding element for  search bar
search = driver.find_element(By.XPATH,"/html/body/div/div[2]/div/div[1]/div/div[1]/div/section[1]/div[1]/div[1]/div[2]/input[1]")
search.send_keys('GK')

# %%
search = driver.find_element(By.XPATH,"/html/body/div/div[2]/div/div[1]/div/div[1]/div/section[1]/div[1]/div[1]/div[2]/input[2]")
search.send_keys(' List of all Prime Ministers of India')

# %%
search = driver.find_element(By.XPATH,"/html/body/div/div[2]/div/div[1]/div/div[1]/div/section[1]/div[1]/div[1]/div[2]/input[2]")
search.send_keys()

# %%
Name =[]
Born_Dead =[]
Term_of_office =[]
Remarks =[]

# %%
name_tags=driver.find_elements(By.XPATH,"//a[@target='_blank']")
for i in name_tags[0:]:
    name=i.text
    name_tags.append(name)

# %%
Born_Dead_tags=driver.find_elements(By.XPATH,"//td[@valign='top']")
for i in Born_Dead_tags[0:-1]:
    Born_Dead=i.text
    Born_Dead_tags.append(Born_Dead)
    
    
Term_of_office_tags=driver.find_elements(By.XPATH,"//td[@valign='top']")
for i in Term_of_office_tags[0:-1]:
    Term_of_office=i.text
    Term_of_office_tags.append(Term_of_office)
    
    
    
    
    

Remarks_tags=driver.find_elements(By.XPATH,"//td[@valign='top']")
for i in Remarks_tags[0:-1]:
    Remarks=i.text
    Remarks_tags.append(Remarks)

# %%
df=pd.DataFrame({})
df['PM name']=name_tags

df
# Out:
#                                                PM name
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# 4    <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                 ...
# 193
# 194
# 195
# 196
# 197
#
# [198 rows x 1 columns]

# %%
df=pd.DataFrame({})
df['Born_Dead']=Born_Dead_tags
df['Term_of_office']=Term_of_office_tags
df['Remarks']=Remarks_tags
df
# Out:
#                                              Born_Dead  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# 4    <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                 ...
# 164                                      First Sikh PM
# 165                                                18.
# 166                                      Narendra Modi
# 167                                        (born 1950)
# 168                              26 May 2014 - Present
#
#                                         Term_of_office  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# ## Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpagehttps://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on leftside.
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe

# %%
# connect to the driver

driver = webdriver.Chrome(r"chromedriver.exe")

# %%
url = 'https://www.motor1.com/'
driver.get(url)

# %%
# finding element for job search bar
search = driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/div/div[3]/div/div/button")
search.send_keys('50 Most expensive cars')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
search.send_keys()

# %%
name_tags=driver.find_elements(By.XPATH,"//h3[@class='subheader']")
for i in name_tags[0:]:
    name=i.text
    name_tags.append(name)
    
    
    
    
    
price_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p[28]")
for i in price_tags[0:]:
    price=i.text
    price_tags.append(price)

# %%
df=pd.DataFrame({})
df['Car_name']=name_tags

df
# Out:
#                                               Car_name
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# 4    <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                 ...
# 97                             Bugatti Chiron Profilée
# 98                                Rolls-Royce Sweptail
# 99                            Bugatti La Voiture Noire
# 100                             Rolls-Royce Boat Tail*
# 101                   Most Expensive Cars In The World
#
# [102 rows x 1 columns]
